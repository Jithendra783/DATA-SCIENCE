# %% [markdown]
# ## CHINTAPALLI JITHENDRA DURGA KUMAR

# %% [markdown]
# CB.EN.U4CSE20213

# %%
import pandas as pd

# %% [markdown]
# 1.

# %%
df=pd.read_csv("/content/Absenteeism_at_work.csv")

# %% [markdown]
# 2.

# %%
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %% [markdown]
# Transportation expense,
# son is not required

# %%
df.drop(columns=['Transportation expense','Son'])
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Distance from Residence to Work  Service time  Age  \
# ...

# %% [markdown]
# 3.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    float64
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %% [markdown]
# There arent any missing values so no need to correct them. If there are any we can correct them by fillna() method by filling with mean() or median() or mode().

# %% [markdown]
# 4.

# %% [markdown]
# Lets do outlier analysis for Body mass index

# %%
df.boxplot("Body mass index")

# %% [markdown]
# There are no outliers for column Body mass index

# %% [markdown]
# Now lets do outlier analysis for Absenteeism time in hours

# %%
df.boxplot("Absenteeism time in hours")

# %% [markdown]
# This column has too many outliers(>20).

# %%
df.boxplot()

# %% [markdown]
# 5.

# %%
df.corr()
# Out:
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.064245
# Reason for absence              -0.064245            1.000000
# Month of absence                -0.000043           -0.083858
# Day of the week                  0.034468            0.116319
# Seasons                          0.098495           -0.117925
# Transportation expense          -0.224163           -0.119381
# Distance from Residence to Work -0.486160            0.161831
# Service time                    -0.272704            0.048425
# Age                              0.040899           -0.078608
# Work load Average/day            0.092457           -0.123472
# Hit target                       0.018789            0.088943
# Disciplinary failure             0.004502           -0.545054
# Education                       -0.036254           -0.047357
# Son                              0.002767           -0.055364
# ...

# %% [markdown]
# 6.

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %% [markdown]
# 7.

# %%
df.head(3)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0                 239.554  ...                     0          1    2
# 1                 239.554  ...                     1          1    1
# 2                 239.554  ...                     0          1    0
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# ...

# %% [markdown]
# 8.

# %%
df.tail(4)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 736   37                 264.604  ...                     0          3    1
# ...

# %% [markdown]
# 9.

# %%
df.iloc[213]
# Out:
# ID                                   7.000
# Reason for absence                   0.000
# Month of absence                     5.000
# Day of the week                      4.000
# Seasons                              3.000
# Transportation expense             279.000
# Distance from Residence to Work      5.000
# Service time                        14.000
# Age                                 39.000
# Work load Average/day              378.884
# Hit target                          92.000
# Disciplinary failure                 1.000
# Education                            1.000
# Son                                  2.000
# Social drinker                       1.000
# Social smoker                        1.000
# Pet                                  0.000
# Weight                              68.000
# Height                             168.000
# Body mass index                     24.000
# Absenteeism time in hours            0.000
# Name: 213, dtype: float64

# %% [markdown]
# 10.

# %%
len(df)
# Out:
# 740

# %% [markdown]
# 11.

# %%
df.iloc[0,:5]
# Out:
# ID                    11.0
# Reason for absence    26.0
# Month of absence       7.0
# Day of the week        3.0
# Seasons                1.0
# Name: 0, dtype: float64

# %% [markdown]
# 12.

# %%
df[df['Reason for absence']==9].shape[0]
# Out:
# 4

# %% [markdown]
# Therefore 4 people are affected with the diseases of circulatory system

# %% [markdown]
# 13.

# %%
df.groupby('Body mass index',key=["overweight","obese"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-53a9653bde85> in <module>
# ----> 1 df.groupby('Body mass index',key=["overweight","obese"])
#
# TypeError: groupby() got an unexpected keyword argument 'key'

# %% [markdown]
# 14.

# %%
df.mean()
# Out:
# ID                                  18.017568
# Reason for absence                  19.216216
# Month of absence                     6.324324
# Day of the week                      3.914865
# Seasons                              2.544595
# Transportation expense             221.329730
# Distance from Residence to Work     29.631081
# Service time                        12.554054
# Age                                 36.450000
# Work load Average/day              271.490235
# Hit target                          94.587838
# Disciplinary failure                 0.054054
# Education                            1.291892
# Son                                  1.018919
# Social drinker                       0.567568
# Social smoker                        0.072973
# Pet                                  0.745946
# Weight                              79.035135
# Height                             172.114865
# Body mass index                     26.677027
# ...

# %%
df.std()
# Out:
# ID                                 11.021247
# Reason for absence                  8.433406
# Month of absence                    3.436287
# Day of the week                     1.421675
# Seasons                             1.111831
# Transportation expense             66.952223
# Distance from Residence to Work    14.836788
# Service time                        4.384873
# Age                                 6.478772
# Work load Average/day              39.058116
# Hit target                          3.779313
# Disciplinary failure                0.226277
# Education                           0.673238
# Son                                 1.098489
# Social drinker                      0.495749
# Social smoker                       0.260268
# Pet                                 1.318258
# Weight                             12.883211
# Height                              6.034995
# Body mass index                     4.285452
# Absenteeism time in hours          13.330998
# ...

# %%
df.groupby(["Education"]).mean()["Age"]
# Out:
# Education
# 1    37.142390
# 2    34.000000
# 3    32.291139
# 4    41.000000
# Name: Age, dtype: float64

# %% [markdown]
# Education - 1:Highschool
# 2:graduates
# 3.postgraduates

# %% [markdown]
# 15.

# %%
df["Transportation expense"].mean()
# Out:
# 221.32972972972973

# %%
df["Transportation expense"].var()
# Out:
# 4482.600197491131

# %% [markdown]
# 16.

# %%
df["Social drinker"].hist(bins=20)

# %%
df.skew()
# Out:
# ID                                 0.016606
# Reason for absence                -0.915312
# Month of absence                   0.069369
# Day of the week                    0.102440
# Seasons                           -0.038532
# Transportation expense             0.396189
# Distance from Residence to Work    0.312083
# Service time                      -0.004720
# Age                                0.697703
# Work load Average/day              0.961457
# Hit target                        -1.261708
# Disciplinary failure               3.952270
# Education                          2.108953
# Son                                1.086465
# Social drinker                    -0.273327
# Social smoker                      3.290333
# Pet                                2.735715
# Weight                             0.017001
# Height                             2.566060
# Body mass index                    0.305046
# Absenteeism time in hours          5.720728
# dtype: float64

# %% [markdown]
# negative skew
